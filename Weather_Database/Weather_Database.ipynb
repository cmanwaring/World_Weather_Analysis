# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Weather API Key
from config import weather_api_key

# %%
# 3) Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=eec9a707f9a779d5b6765c629d18cc50

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# 4) Get the nearest city using the bitipy module.
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
#                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | phoenix
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | vao
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | birjand
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | port hardy
# Processing Record 13 of Set 1 | raga
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | tayoltita
# Processing Record 16 of Set 1 | fortuna
# Processing Record 17 of Set 1 | korla
# Processing Record 18 of Set 1 | cap-aux-meules
# Processing Record 19 of Set 1 | la ciotat
# Processing Record 20 of Set 1 | axim
# Processing Record 21 of Set 1 | topchikha
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | roma
# Processing Record 24 of Set 1 | salalah
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | loandjili
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | sao filipe
# Processing Record 33 of Set 1 | tuatapere
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | la ronge
# Processing Record 36 of Set 1 | porto novo
# Processing Record 37 of Set 1 | nanortalik
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | pangody
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 1 | henties bay
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | seoul
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | abnub
# Processing Record 4 of Set 2 | ilinskiy
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | comodoro rivadavia
# Processing Record 7 of Set 2 | bitung
# Processing Record 8 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | nuuk
# Processing Record 11 of Set 2 | yakeshi
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | puerto del rosario
# Processing Record 16 of Set 2 | venado tuerto
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | guerrero negro
# Processing Record 19 of Set 2 | waddan
# Processing Record 20 of Set 2 | souillac
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | kambove
# Processing Record 23 of Set 2 | belmonte
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | sinnamary
# Processing Record 28 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 2 | cockburn town
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | oliveira dos brejinhos
# Processing Record 36 of Set 2 | sayyan
# Processing Record 37 of Set 2 | rundu
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | vicksburg
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | adrar
# Processing Record 42 of Set 2 | port blair
# Processing Record 43 of Set 2 | flin flon
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | sao jose da coroa grande
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | payo
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | andenes
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | bobrovytsya
# Processing Record 3 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | poum
# Processing Record 6 of Set 3 | gravdal
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | union
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | walvis bay
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | contamana
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | andra
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | kailua
# Processing Record 19 of Set 3 | aulnoye-aymeries
# Processing Record 20 of Set 3 | college
# Processing Record 21 of Set 3 | newport
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | wodonga
# Processing Record 24 of Set 3 | katherine
# Processing Record 25 of Set 3 | faya
# Processing Record 26 of Set 3 | voh
# Processing Record 27 of Set 3 | blatec
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | aksay
# Processing Record 30 of Set 3 | aklavik
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | vardo
# Processing Record 33 of Set 3 | gornopravdinsk
# Processing Record 34 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | bowling green
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | tahta
# Processing Record 39 of Set 3 | ponta delgada
# Processing Record 40 of Set 3 | warri
# Processing Record 41 of Set 3 | bayir
# Processing Record 42 of Set 3 | urengoy
# Processing Record 43 of Set 3 | abalak
# Processing Record 44 of Set 3 | grindavik
# Processing Record 45 of Set 3 | bonfim
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | saint-georges
# Processing Record 50 of Set 3 | navalcarnero
# Processing Record 1 of Set 4 | margate
# Processing Record 2 of Set 4 | kanlagay
# Processing Record 3 of Set 4 | mayo
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | isangel
# Processing Record 6 of Set 4 | antalya
# Processing Record 7 of Set 4 | xining
# Processing Record 8 of Set 4 | enumclaw
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | pali
# Processing Record 14 of Set 4 | labuhan
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | northam
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | puqi
# Processing Record 22 of Set 4 | vila franca do campo
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | marrakesh
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | bagepalli
# Processing Record 27 of Set 4 | praia
# Processing Record 28 of Set 4 | portland
# Processing Record 29 of Set 4 | wonthaggi
# Processing Record 30 of Set 4 | kurunegala
# Processing Record 31 of Set 4 | helong
# Processing Record 32 of Set 4 | palmer
# Processing Record 33 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 4 | quatre cocos
# Processing Record 35 of Set 4 | ajdabiya
# Processing Record 36 of Set 4 | grandview
# Processing Record 37 of Set 4 | chicama
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | matay
# Processing Record 40 of Set 4 | nabire
# Processing Record 41 of Set 4 | tiarei
# Processing Record 42 of Set 4 | san juan
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | sao joao da barra
# Processing Record 46 of Set 4 | balkhash
# Processing Record 47 of Set 4 | abbeville
# Processing Record 48 of Set 4 | meulaboh
# Processing Record 49 of Set 4 | hornepayne
# Processing Record 50 of Set 4 | kargasok
# Processing Record 1 of Set 5 | samarai
# Processing Record 2 of Set 5 | haapiti
# Processing Record 3 of Set 5 | tibu
# Processing Record 4 of Set 5 | itarema
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | kupang
# Processing Record 7 of Set 5 | adeje
# Processing Record 8 of Set 5 | atuona
# Processing Record 9 of Set 5 | roald
# Processing Record 10 of Set 5 | port augusta
# Processing Record 11 of Set 5 | chapais
# Processing Record 12 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 5 | paamiut
# Processing Record 14 of Set 5 | imeni poliny osipenko
# Processing Record 15 of Set 5 | muyezerskiy
# Processing Record 16 of Set 5 | hamilton
# Processing Record 17 of Set 5 | yumen
# Processing Record 18 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 5 | si satchanalai
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | moanda
# Processing Record 22 of Set 5 | charagua
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 5 | kamaishi
# Processing Record 26 of Set 5 | nelson bay
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | lebedinyy
# Processing Record 29 of Set 5 | port moresby
# Processing Record 30 of Set 5 | usuki
# Processing Record 31 of Set 5 | barcelona
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | rio bravo
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | baft
# Processing Record 37 of Set 5 | eureka
# Processing Record 38 of Set 5 | hambantota
# Processing Record 39 of Set 5 | richards bay
# Processing Record 40 of Set 5 | malanville
# Processing Record 41 of Set 5 | savannakhet
# Processing Record 42 of Set 5 | amapa
# Processing Record 43 of Set 5 | tabuk
# Processing Record 44 of Set 5 | pudozh
# Processing Record 45 of Set 5 | matara
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | victoria
# Processing Record 48 of Set 5 | ho
# City not found. Skipping...
# Processing Record 49 of Set 5 | tiksi
# Processing Record 50 of Set 5 | warmbad
# Processing Record 1 of Set 6 | hamburg
# Processing Record 2 of Set 6 | kodiak
# Processing Record 3 of Set 6 | kavadarci
# Processing Record 4 of Set 6 | inirida
# Processing Record 5 of Set 6 | simao
# Processing Record 6 of Set 6 | bokhan
# Processing Record 7 of Set 6 | bathsheba
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | alofi
# Processing Record 10 of Set 6 | muros
# Processing Record 11 of Set 6 | kudahuvadhoo
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | fairbanks
# Processing Record 14 of Set 6 | tynda
# Processing Record 15 of Set 6 | garmsar
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | kenai
# Processing Record 18 of Set 6 | bilibino
# Processing Record 19 of Set 6 | cazaje
# City not found. Skipping...
# Processing Record 20 of Set 6 | tocopilla
# Processing Record 21 of Set 6 | oranjemund
# Processing Record 22 of Set 6 | taltal
# Processing Record 23 of Set 6 | formosa do rio preto
# Processing Record 24 of Set 6 | kalabo
# Processing Record 25 of Set 6 | santiago de cao
# Processing Record 26 of Set 6 | saint-augustin
# Processing Record 27 of Set 6 | kibala
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | bambanglipuro
# Processing Record 30 of Set 6 | rincon
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | hobyo
# Processing Record 33 of Set 6 | vila velha
# Processing Record 34 of Set 6 | japura
# Processing Record 35 of Set 6 | edmundston
# Processing Record 36 of Set 6 | te anau
# Processing Record 37 of Set 6 | hovd
# Processing Record 38 of Set 6 | mayumba
# Processing Record 39 of Set 6 | rjukan
# Processing Record 40 of Set 6 | whyalla
# Processing Record 41 of Set 6 | rangkasbitung
# Processing Record 42 of Set 6 | sechura
# Processing Record 43 of Set 6 | balabac
# Processing Record 44 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | thinadhoo
# Processing Record 46 of Set 6 | luanda
# Processing Record 47 of Set 6 | swellendam
# Processing Record 48 of Set 6 | gobabis
# Processing Record 49 of Set 6 | teahupoo
# Processing Record 50 of Set 6 | umm lajj
# Processing Record 1 of Set 7 | castro
# Processing Record 2 of Set 7 | barkhan
# Processing Record 3 of Set 7 | tucuma
# Processing Record 4 of Set 7 | provideniya
# Processing Record 5 of Set 7 | yerbogachen
# Processing Record 6 of Set 7 | ayorou
# Processing Record 7 of Set 7 | severo-kurilsk
# Processing Record 8 of Set 7 | baruun-urt
# Processing Record 9 of Set 7 | staryy nadym
# Processing Record 10 of Set 7 | simpang
# Processing Record 11 of Set 7 | kerema
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | ust-kut
# Processing Record 14 of Set 7 | namatanai
# Processing Record 15 of Set 7 | srednekolymsk
# Processing Record 16 of Set 7 | vera cruz
# Processing Record 17 of Set 7 | saint-philippe
# Processing Record 18 of Set 7 | coihaique
# Processing Record 19 of Set 7 | laurel
# Processing Record 20 of Set 7 | midland
# Processing Record 21 of Set 7 | brandon
# Processing Record 22 of Set 7 | garowe
# Processing Record 23 of Set 7 | chany
# Processing Record 24 of Set 7 | ahipara
# Processing Record 25 of Set 7 | messina
# Processing Record 26 of Set 7 | dapaong
# Processing Record 27 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | flagstaff
# Processing Record 29 of Set 7 | besuki
# Processing Record 30 of Set 7 | port said
# Processing Record 31 of Set 7 | atakpame
# Processing Record 32 of Set 7 | kalmunai
# Processing Record 33 of Set 7 | thonon-les-bains
# Processing Record 34 of Set 7 | chas
# Processing Record 35 of Set 7 | oriximina
# Processing Record 36 of Set 7 | saint-francois
# Processing Record 37 of Set 7 | sur
# Processing Record 38 of Set 7 | havre-saint-pierre
# Processing Record 39 of Set 7 | agirish
# Processing Record 40 of Set 7 | hokitika
# Processing Record 41 of Set 7 | bima
# Processing Record 42 of Set 7 | bud
# Processing Record 43 of Set 7 | husavik
# Processing Record 44 of Set 7 | balaipungut
# Processing Record 45 of Set 7 | jepara
# Processing Record 46 of Set 7 | arandis
# Processing Record 47 of Set 7 | kasangulu
# Processing Record 48 of Set 7 | clarence town
# Processing Record 49 of Set 7 | lundazi
# Processing Record 50 of Set 7 | sosnovo-ozerskoye
# Processing Record 1 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 8 | hasaki
# Processing Record 4 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 8 | emerald
# Processing Record 6 of Set 8 | aykhal
# Processing Record 7 of Set 8 | saint george
# Processing Record 8 of Set 8 | pauini
# Processing Record 9 of Set 8 | timmins
# Processing Record 10 of Set 8 | faanui
# Processing Record 11 of Set 8 | taoudenni
# Processing Record 12 of Set 8 | akyab
# Processing Record 13 of Set 8 | hryshkivtsi
# Processing Record 14 of Set 8 | gambela
# Processing Record 15 of Set 8 | carlyle
# Processing Record 16 of Set 8 | nuevo casas grandes
# Processing Record 17 of Set 8 | abu samrah
# Processing Record 18 of Set 8 | mayor pablo lagerenza
# Processing Record 19 of Set 8 | san andres
# Processing Record 20 of Set 8 | stony plain
# Processing Record 21 of Set 8 | marfino
# Processing Record 22 of Set 8 | honiara
# Processing Record 23 of Set 8 | dingle
# Processing Record 24 of Set 8 | tura
# Processing Record 25 of Set 8 | penzance
# Processing Record 26 of Set 8 | marystown
# Processing Record 27 of Set 8 | pacific grove
# Processing Record 28 of Set 8 | chimbote
# Processing Record 29 of Set 8 | beira
# Processing Record 30 of Set 8 | furano
# Processing Record 31 of Set 8 | boguchany
# Processing Record 32 of Set 8 | sablan
# Processing Record 33 of Set 8 | camacha
# Processing Record 34 of Set 8 | harrisonburg
# Processing Record 35 of Set 8 | maralal
# Processing Record 36 of Set 8 | aasiaat
# Processing Record 37 of Set 8 | alta floresta
# Processing Record 38 of Set 8 | harlingen
# Processing Record 39 of Set 8 | jacareacanga
# Processing Record 40 of Set 8 | karratha
# Processing Record 41 of Set 8 | tibacuy
# Processing Record 42 of Set 8 | abha
# Processing Record 43 of Set 8 | bilma
# Processing Record 44 of Set 8 | saint-denis
# Processing Record 45 of Set 8 | lamar
# Processing Record 46 of Set 8 | cam ranh
# Processing Record 47 of Set 8 | lata
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | khlong luang
# Processing Record 50 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 1 of Set 9 | am timan
# Processing Record 2 of Set 9 | santa maria da vitoria
# Processing Record 3 of Set 9 | kamenka
# Processing Record 4 of Set 9 | fukumitsu
# Processing Record 5 of Set 9 | great yarmouth
# Processing Record 6 of Set 9 | cap malheureux
# Processing Record 7 of Set 9 | caribou
# Processing Record 8 of Set 9 | puerto ayora
# Processing Record 9 of Set 9 | manuk mangkaw
# Processing Record 10 of Set 9 | vikulovo
# Processing Record 11 of Set 9 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 12 of Set 9 | hinton
# Processing Record 13 of Set 9 | concarneau
# Processing Record 14 of Set 9 | kang
# Processing Record 15 of Set 9 | miranda
# Processing Record 16 of Set 9 | mamakan
# Processing Record 17 of Set 9 | homer
# Processing Record 18 of Set 9 | eyl
# Processing Record 19 of Set 9 | elizabeth city
# Processing Record 20 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 9 | half moon bay
# Processing Record 22 of Set 9 | komsomolskiy
# Processing Record 23 of Set 9 | mananjary
# Processing Record 24 of Set 9 | luderitz
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | keffi
# Processing Record 27 of Set 9 | mastic beach
# Processing Record 28 of Set 9 | bhongir
# Processing Record 29 of Set 9 | zhirnovsk
# Processing Record 30 of Set 9 | jumla
# Processing Record 31 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 9 | cayenne
# Processing Record 33 of Set 9 | majene
# Processing Record 34 of Set 9 | cascais
# Processing Record 35 of Set 9 | kaitangata
# Processing Record 36 of Set 9 | lasa
# Processing Record 37 of Set 9 | knysna
# Processing Record 38 of Set 9 | yabelo
# Processing Record 39 of Set 9 | san policarpo
# Processing Record 40 of Set 9 | broken hill
# Processing Record 41 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 42 of Set 9 | hohhot
# Processing Record 43 of Set 9 | zaysan
# Processing Record 44 of Set 9 | ugoofaaru
# Processing Record 45 of Set 9 | camana
# Processing Record 46 of Set 9 | birao
# Processing Record 47 of Set 9 | powell
# Processing Record 48 of Set 9 | crixas
# Processing Record 49 of Set 9 | cravo norte
# Processing Record 50 of Set 9 | yazman
# Processing Record 1 of Set 10 | chalon-sur-saone
# Processing Record 2 of Set 10 | deputatskiy
# Processing Record 3 of Set 10 | naze
# Processing Record 4 of Set 10 | atbasar
# Processing Record 5 of Set 10 | mount isa
# Processing Record 6 of Set 10 | aktau
# Processing Record 7 of Set 10 | coahuayana
# Processing Record 8 of Set 10 | san patricio
# Processing Record 9 of Set 10 | sitka
# Processing Record 10 of Set 10 | vestmanna
# Processing Record 11 of Set 10 | asau
# Processing Record 12 of Set 10 | kasongo-lunda
# Processing Record 13 of Set 10 | arlit
# Processing Record 14 of Set 10 | westport
# Processing Record 15 of Set 10 | plettenberg bay
# Processing Record 16 of Set 10 | aksarka
# Processing Record 17 of Set 10 | tateyama
# Processing Record 18 of Set 10 | umm kaddadah
# Processing Record 19 of Set 10 | srivardhan
# Processing Record 20 of Set 10 | abu kamal
# Processing Record 21 of Set 10 | urumqi
# Processing Record 22 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 10 | salina
# Processing Record 24 of Set 10 | mnogovershinnyy
# Processing Record 25 of Set 10 | promyshlennovskiy
# Processing Record 26 of Set 10 | kununurra
# Processing Record 27 of Set 10 | mina
# Processing Record 28 of Set 10 | tortosa
# Processing Record 29 of Set 10 | gwadar
# Processing Record 30 of Set 10 | kencong
# Processing Record 31 of Set 10 | maputo
# Processing Record 32 of Set 10 | okhtyrka
# Processing Record 33 of Set 10 | san isidro
# Processing Record 34 of Set 10 | lyubashivka
# Processing Record 35 of Set 10 | red bluff
# Processing Record 36 of Set 10 | bacolod
# Processing Record 37 of Set 10 | miquelon
# Processing Record 38 of Set 10 | tawau
# Processing Record 39 of Set 10 | mitsamiouli
# Processing Record 40 of Set 10 | shache
# Processing Record 41 of Set 10 | daru
# Processing Record 42 of Set 10 | manzil salim
# Processing Record 43 of Set 10 | gdov
# Processing Record 44 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 10 | nakamura
# Processing Record 46 of Set 10 | caravelas
# Processing Record 47 of Set 10 | dzaoudzi
# Processing Record 48 of Set 10 | sattahip
# Processing Record 49 of Set 10 | pangnirtung
# Processing Record 50 of Set 10 | saint-jean-port-joli
# Processing Record 1 of Set 11 | tessalit
# Processing Record 2 of Set 11 | ixtapa
# Processing Record 3 of Set 11 | uinskoye
# Processing Record 4 of Set 11 | porto velho
# Processing Record 5 of Set 11 | mapimi
# Processing Record 6 of Set 11 | krasnoselkup
# Processing Record 7 of Set 11 | saint stephen
# Processing Record 8 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 11 | yatou
# Processing Record 10 of Set 11 | sisimiut
# Processing Record 11 of Set 11 | thunder bay
# Processing Record 12 of Set 11 | stutterheim
# Processing Record 13 of Set 11 | zhumadian
# Processing Record 14 of Set 11 | baturaja
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | lovozero
# Processing Record 17 of Set 11 | visnes
# Processing Record 18 of Set 11 | tashtagol
# Processing Record 19 of Set 11 | ravar
# Processing Record 20 of Set 11 | xichang
# Processing Record 21 of Set 11 | vestmannaeyjar
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | suluq
# Processing Record 24 of Set 11 | bubaque
# Processing Record 25 of Set 11 | carbonia
# Processing Record 26 of Set 11 | salinopolis
# Processing Record 27 of Set 11 | dawson creek
# Processing Record 28 of Set 11 | tekeli
# Processing Record 29 of Set 11 | hun
# Processing Record 30 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 11 | windhoek
# Processing Record 32 of Set 11 | hirara
# Processing Record 33 of Set 11 | avera
# Processing Record 34 of Set 11 | inverell
# Processing Record 35 of Set 11 | nhulunbuy
# Processing Record 36 of Set 11 | jiexiu
# Processing Record 37 of Set 11 | owando
# Processing Record 38 of Set 11 | asbestovskiy
# Processing Record 39 of Set 11 | izhma
# Processing Record 40 of Set 11 | clyde river
# Processing Record 41 of Set 11 | havoysund
# Processing Record 42 of Set 11 | iralaya
# Processing Record 43 of Set 11 | sambava
# Processing Record 44 of Set 11 | toamasina
# Processing Record 45 of Set 11 | changji
# Processing Record 46 of Set 11 | mukhen
# Processing Record 47 of Set 11 | sorland
# Processing Record 48 of Set 11 | karpathos
# Processing Record 49 of Set 11 | lafiagi
# Processing Record 50 of Set 11 | sioux lookout
# Processing Record 1 of Set 12 | baoding
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | yola
# Processing Record 4 of Set 12 | khandbari
# Processing Record 5 of Set 12 | gigmoto
# Processing Record 6 of Set 12 | sibolga
# Processing Record 7 of Set 12 | ambilobe
# Processing Record 8 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 12 | scarborough
# Processing Record 10 of Set 12 | savelugu
# Processing Record 11 of Set 12 | villa constitucion
# Processing Record 12 of Set 12 | pandan
# Processing Record 13 of Set 12 | padang
# Processing Record 14 of Set 12 | lixourion
# Processing Record 15 of Set 12 | antofagasta
# Processing Record 16 of Set 12 | bandarbeyla
# Processing Record 17 of Set 12 | tromso
# Processing Record 18 of Set 12 | zelenets
# Processing Record 19 of Set 12 | kushmurun
# Processing Record 20 of Set 12 | krasnovishersk
# Processing Record 21 of Set 12 | progreso
# Processing Record 22 of Set 12 | okha
# Processing Record 23 of Set 12 | jiwani
# Processing Record 24 of Set 12 | albert lea
# Processing Record 25 of Set 12 | kralendijk
# Processing Record 26 of Set 12 | rameswaram
# Processing Record 27 of Set 12 | myaundzha
# Processing Record 28 of Set 12 | broome
# Processing Record 29 of Set 12 | galesong
# Processing Record 30 of Set 12 | mwanza
# Processing Record 31 of Set 12 | port shepstone
# Processing Record 32 of Set 12 | chepareria
# Processing Record 33 of Set 12 | thurso
# Processing Record 34 of Set 12 | bukama
# Processing Record 35 of Set 12 | natitingou
# Processing Record 36 of Set 12 | ozu
# Processing Record 37 of Set 12 | acapulco
# Processing Record 38 of Set 12 | puyo
# Processing Record 39 of Set 12 | klaksvik
# Processing Record 40 of Set 12 | rocha
# Processing Record 41 of Set 12 | tautira
# Processing Record 42 of Set 12 | ilhabela
# Processing Record 43 of Set 12 | concepcion del uruguay
# Processing Record 44 of Set 12 | letnyaya stavka
# Processing Record 45 of Set 12 | micheweni
# Processing Record 46 of Set 12 | saint anthony
# Processing Record 47 of Set 12 | albury
# Processing Record 48 of Set 12 | camrose
# Processing Record 49 of Set 12 | santa brigida
# Processing Record 50 of Set 12 | vung tau
# Processing Record 1 of Set 13 | jiaozuo
# Processing Record 2 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 13 | alanya
# Processing Record 4 of Set 13 | qasigiannguit
# Processing Record 5 of Set 13 | rawson
# Processing Record 6 of Set 13 | ornskoldsvik
# Processing Record 7 of Set 13 | bakel
# Processing Record 8 of Set 13 | sorata
# Processing Record 9 of Set 13 | tarrafal
# Processing Record 10 of Set 13 | pemangkat
# Processing Record 11 of Set 13 | kargopol
# Processing Record 12 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 13 | doha
# Processing Record 14 of Set 13 | madras
# Processing Record 15 of Set 13 | amahai
# Processing Record 16 of Set 13 | krasnooktyabrskiy
# Processing Record 17 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 13 | amalapuram
# Processing Record 19 of Set 13 | mansa
# Processing Record 20 of Set 13 | cozumel
# Processing Record 21 of Set 13 | lezajsk
# Processing Record 22 of Set 13 | logrono
# Processing Record 23 of Set 13 | porto belo
# Processing Record 24 of Set 13 | anloga
# Processing Record 25 of Set 13 | qaqortoq
# Processing Record 26 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 27 of Set 13 | goderich
# Processing Record 28 of Set 13 | berlevag
# Processing Record 29 of Set 13 | cherepovets
# Processing Record 30 of Set 13 | port lincoln
# Processing Record 31 of Set 13 | burica
# City not found. Skipping...
# Processing Record 32 of Set 13 | mathbaria
# Processing Record 33 of Set 13 | bonavista
# Processing Record 34 of Set 13 | poya
# Processing Record 35 of Set 13 | caconda
# Processing Record 36 of Set 13 | yaan
# Processing Record 37 of Set 13 | havelock
# Processing Record 38 of Set 13 | hami
# Processing Record 39 of Set 13 | kayerkan
# Processing Record 40 of Set 13 | bucsa
# Processing Record 41 of Set 13 | keti bandar
# Processing Record 42 of Set 13 | zaragoza
# Processing Record 43 of Set 13 | smithers
# Processing Record 44 of Set 13 | jennings
# Processing Record 45 of Set 13 | pizarro
# Processing Record 46 of Set 13 | puerto cabezas
# Processing Record 47 of Set 13 | arrecife
# Processing Record 48 of Set 13 | altay
# Processing Record 49 of Set 13 | nalut
# Processing Record 50 of Set 13 | ryzdvyanyy
# Processing Record 1 of Set 14 | tiznit
# Processing Record 2 of Set 14 | kulhudhuffushi
# Processing Record 3 of Set 14 | stryn
# Processing Record 4 of Set 14 | vilhena
# Processing Record 5 of Set 14 | shimanovsk
# Processing Record 6 of Set 14 | vallentuna
# Processing Record 7 of Set 14 | sokyryany
# Processing Record 8 of Set 14 | mayskiy
# Processing Record 9 of Set 14 | mongoumba
# Processing Record 10 of Set 14 | abilene
# Processing Record 11 of Set 14 | omsukchan
# Processing Record 12 of Set 14 | caledon
# Processing Record 13 of Set 14 | zhigansk
# Processing Record 14 of Set 14 | vostok
# Processing Record 15 of Set 14 | pochutla
# Processing Record 16 of Set 14 | majengo
# Processing Record 17 of Set 14 | san lawrenz
# Processing Record 18 of Set 14 | kiama
# Processing Record 19 of Set 14 | mhlume
# Processing Record 20 of Set 14 | kosh-agach
# Processing Record 21 of Set 14 | santa ana
# Processing Record 22 of Set 14 | kieta
# Processing Record 23 of Set 14 | tazovskiy
# Processing Record 24 of Set 14 | la palma
# Processing Record 25 of Set 14 | lagos
# Processing Record 26 of Set 14 | chokwe
# Processing Record 27 of Set 14 | van buren
# Processing Record 28 of Set 14 | carcassonne
# Processing Record 29 of Set 14 | sokode
# Processing Record 30 of Set 14 | sunnyside
# Processing Record 31 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 32 of Set 14 | harper
# Processing Record 33 of Set 14 | hwange
# Processing Record 34 of Set 14 | lugovoy
# Processing Record 35 of Set 14 | ikornnes
# Processing Record 36 of Set 14 | sena madureira
# Processing Record 37 of Set 14 | gryfice
# Processing Record 38 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 14 | ashington
# Processing Record 40 of Set 14 | hit
# Processing Record 41 of Set 14 | matagami
# Processing Record 42 of Set 14 | dolores
# Processing Record 43 of Set 14 | yeniseysk
# Processing Record 44 of Set 14 | bournemouth
# Processing Record 45 of Set 14 | larsnes
# Processing Record 46 of Set 14 | rostock
# Processing Record 47 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 14 | stokke
# Processing Record 49 of Set 14 | toowoomba
# Processing Record 50 of Set 14 | khani
# Processing Record 1 of Set 15 | luau
# Processing Record 2 of Set 15 | neustadt
# Processing Record 3 of Set 15 | mrakovo
# Processing Record 4 of Set 15 | haapsalu
# Processing Record 5 of Set 15 | yar-sale
# Processing Record 6 of Set 15 | nefteyugansk
# Processing Record 7 of Set 15 | ust-kulom
# Processing Record 8 of Set 15 | grass valley
# Processing Record 9 of Set 15 | kaduqli
# Processing Record 10 of Set 15 | grajau
# Processing Record 11 of Set 15 | mujiayingzi
# Processing Record 12 of Set 15 | altamira
# Processing Record 13 of Set 15 | grand gaube
# Processing Record 14 of Set 15 | honningsvag
# Processing Record 15 of Set 15 | jaciara
# Processing Record 16 of Set 15 | sampit
# Processing Record 17 of Set 15 | bridlington
# Processing Record 18 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 19 of Set 15 | talnakh
# Processing Record 20 of Set 15 | santa rosalia
# Processing Record 21 of Set 15 | envira
# Processing Record 22 of Set 15 | nizhnyaya salda
# Processing Record 23 of Set 15 | wagar
# Processing Record 24 of Set 15 | kutum
# Processing Record 25 of Set 15 | mehamn
# Processing Record 26 of Set 15 | koundara
# Processing Record 27 of Set 15 | quelimane
# Processing Record 28 of Set 15 | nanchang
# Processing Record 29 of Set 15 | kamina
# Processing Record 30 of Set 15 | del rio
# Processing Record 31 of Set 15 | anadyr
# Processing Record 32 of Set 15 | whitehorse
# Processing Record 33 of Set 15 | barvinkove
# Processing Record 34 of Set 15 | zheleznodorozhnyy
# Processing Record 35 of Set 15 | joppatowne
# Processing Record 36 of Set 15 | zheshart
# Processing Record 37 of Set 15 | carballo
# Processing Record 38 of Set 15 | miajadas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# 7) Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Phoenix      US  33.4484 -112.0740     87.01        11          90
# 1      Khatanga      RU  71.9667  102.5000    -11.96        97          41
# 2        Albany      US  42.6001  -73.9662     66.20        42          75
# 3       Mataura      NZ -46.1927  168.8643     60.01        79          57
# 4           Vao      NC -22.6667  167.4833     74.84        79         100
# 5      Katsuura      JP  35.1333  140.3000     52.00        38          77
# 6       Rikitea      PF -23.1203 -134.9692     78.33        69           8
# 7       Birjand      IR  32.8663   59.2211     48.20        71          20
# 8        Avarua      CK -21.2078 -159.7750     82.40        69          40
# 9  Punta Arenas      CL -53.1500  -70.9167     37.40        87           0
#
#    Wind Speed Current Description
# 0       16.11     overcast clouds
# 1        8.61    scattered clouds
# 2        3.44       broken clouds
# 3        4.00       broken clouds
# 4       20.38     overcast clouds
# 5        1.99       broken clouds
# 6        5.68           clear sky
# 7        9.22          few clouds
# 8        4.61    scattered clouds
# 9       17.27           clear sky

# %%
# 8) Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
